# %% [markdown]
# Train specified model.
#
# LSTM model architecture and design inspired by [Alcantara et al.](https://peerj.com/articles/12752)

# %% [markdown]
# # Input parameters here

# %%
# # PARAMETERS # # 
BASE_DIR = '/content/drive/My Drive/CS230_FinalReport/' # your base directory
EXP_TYPE = 'with_physicsinputs'

# Hyperparameters:
LSTM_NODES = 64
DROPOUT_RATE = 0.5
LEARNING_RATE = 0.01
GRAD_LOSS_ALPHA = 0.4

MASK_VALUE = 999.
MAX_TIMESTEPS = 67
if EXP_TYPE == 'with_physicsinputs': NUM_INPUT_FEATS = 42
if EXP_TYPE == 'without_physicsinputs': NUM_INPUT_FEATS = 34
NUM_OUTPUT_FEATS = 2
MODEL_FILENAME = '/content/drive/My Drive/CS230_FinalReport/models/' + EXP_TYPE + '_transformer_stepclass' # where you want to save the model to
BATCH_SIZE = 32
EPOCHS = 100

SEED = 43
# # # # # # # # # #

# %% [markdown]
# # Load libraries and data

# %%
# Mount Drive to access data.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Library imports
import matplotlib.pyplot as plt
import tensorflow as tf
import scipy.io as sio
import numpy as np
import os

# To import own model modules
import sys
sys.path.insert(0, (os.path.join(BASE_DIR, 'src/models')))
from train_model_utils_transformer import *

# %%
# Set the random seed
keras.utils.set_random_seed(SEED)

# %%
# Load in train, dev, arrays.
datadir = os.path.join(BASE_DIR, 'data', 'processed', 'normalized')

X_train = np.load(file=os.path.join(datadir, EXP_TYPE, 'X_train_norm.npy'), allow_pickle=True)
Y_train = np.load(file=os.path.join(datadir, EXP_TYPE, 'Y_train_stepclass.npy'), allow_pickle=True)
X_dev = np.load(file=os.path.join(datadir, EXP_TYPE, 'X_dev_norm.npy'), allow_pickle=True)
Y_dev = np.load(file=os.path.join(datadir, EXP_TYPE, 'Y_dev_stepclass.npy'), allow_pickle=True)

# Check sizes
print(f"X_train len: {X_train.shape[0]}")
print(f"X_dev len: {X_dev.shape[0]}")
# Out:
# X_train len: 5949
# X_dev len: 820

# %% [markdown]
# # Train the model

# %%
# Call build model with selected parameters.

model = build_model(
    NUM_TIMESTEPS = MAX_TIMESTEPS,
    NUM_INPUT_FEATS = NUM_INPUT_FEATS,
    NUM_OUTPUT_FEATS = NUM_OUTPUT_FEATS,
    MASK_VALUE = MASK_VALUE,
    transformer_units = 512,
    num_heads = 8,
    dropout_rate = DROPOUT_RATE,
    dense_act = 'sigmoid',
    learning_rate = LEARNING_RATE
    )

# Print a summary of the model's layers and all the parameters.
model.summary()
# Out:
# Model: "Transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 67, 42)]     0           []
#
#  masking (Masking)              (None, 67, 42)       0           ['input_1[0][0]']
#
#  multi_head_attention (MultiHea  (None, 67, 42)      700458      ['masking[0][0]',
#  dAttention)                                                      'masking[0][0]']
#
#  dropout (Dropout)              (None, 67, 42)       0           ['multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 67, 42)      84          ['dropout[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 67, 512)      22016       ['layer_normalization[0][0]']
#
#  flatten (Flatten)              (None, 34304)        0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2814)         96534270    ['flatten[0][0]']
#
#  reshape (Reshape)              (None, 67, 42)       0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 67, 2)        86          ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 97,256,914
# Trainable params: 97,256,914
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model, and get the fit history.

fit_history = train_model(model,
                          MODEL_FILENAME,
                          X_train, Y_train,
                          X_dev, Y_dev,
                          use_earlystopping = False,
                          shuffle = True,
                          epochs = EPOCHS,
                          batch_size = BATCH_SIZE)

# Save fit history.
np.save(os.path.join(MODEL_FILENAME, 'fit_history.npy'), fit_history.history)
# Out:
# Epoch 1/100
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f9f5fd269e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f9f5fd269e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 186/186 [==============================] - ETA: 0s - loss: -1019468054528.0000 - binary_accuracy: 0.4125
# Epoch 1: val_loss improved from inf to -7922727780352.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 31s 116ms/step - loss: -1019468054528.0000 - binary_accuracy: 0.4125 - val_loss: -7922727780352.0000 - val_binary_accuracy: 0.3814
# Epoch 2/100
# 186/186 [==============================] - ETA: 0s - loss: -55251151355904.0000 - binary_accuracy: 0.4063
# Epoch 2: val_loss improved from -7922727780352.00000 to -197170523275264.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 23s 126ms/step - loss: -55251151355904.0000 - binary_accuracy: 0.4063 - val_loss: -197170523275264.0000 - val_binary_accuracy: 0.3616
# Epoch 3/100
# 186/186 [==============================] - ETA: 0s - loss: -450705982750720.0000 - binary_accuracy: 0.4064
# Epoch 3: val_loss improved from -197170523275264.00000 to -1124632555945984.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 23s 123ms/step - loss: -450705982750720.0000 - binary_accuracy: 0.4064 - val_loss: -1124632555945984.0000 - val_binary_accuracy: 0.3680
# Epoch 4/100
# 186/186 [==============================] - ETA: 0s - loss: -1764998556680192.0000 - binary_accuracy: 0.4069
# Epoch 4: val_loss improved from -1124632555945984.00000 to -3656225665318912.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 30s 161ms/step - loss: -1764998556680192.0000 - binary_accuracy: 0.4069 - val_loss: -3656225665318912.0000 - val_binary_accuracy: 0.3817
# Epoch 5/100
# 186/186 [==============================] - ETA: 0s - loss: -4772863475187712.0000 - binary_accuracy: 0.4065
# Epoch 5: val_loss improved from -3656225665318912.00000 to -8846872420548608.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 25s 136ms/step - loss: -4772863475187712.0000 - binary_accuracy: 0.4065 - val_loss: -8846872420548608.0000 - val_binary_accuracy: 0.3752
# Epoch 6/100
# 186/186 [==============================] - ETA: 0s - loss: -10359392398475264.0000 - binary_accuracy: 0.4065
# Epoch 6: val_loss improved from -8846872420548608.00000 to -17831789384957952.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 24s 130ms/step - loss: -10359392398475264.0000 - binary_accuracy: 0.4065 - val_loss: -17831789384957952.0000 - val_binary_accuracy: 0.3847
# Epoch 7/100
# 186/186 [==============================] - ETA: 0s - loss: -19476431146844160.0000 - binary_accuracy: 0.4083
# Epoch 7: val_loss improved from -17831789384957952.00000 to -31818635999707136.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 29s 154ms/step - loss: -19476431146844160.0000 - binary_accuracy: 0.4083 - val_loss: -31818635999707136.0000 - val_binary_accuracy: 0.3817
# Epoch 8/100
# 186/186 [==============================] - ETA: 0s - loss: -33093966408712192.0000 - binary_accuracy: 0.4067
# Epoch 8: val_loss improved from -31818635999707136.00000 to -52028477909499904.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 24s 129ms/step - loss: -33093966408712192.0000 - binary_accuracy: 0.4067 - val_loss: -52028477909499904.0000 - val_binary_accuracy: 0.3817
# Epoch 9/100
# 186/186 [==============================] - ETA: 0s - loss: -52197313073905664.0000 - binary_accuracy: 0.4063
# Epoch 9: val_loss improved from -52028477909499904.00000 to -79708399670919168.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 28s 151ms/step - loss: -52197313073905664.0000 - binary_accuracy: 0.4063 - val_loss: -79708399670919168.0000 - val_binary_accuracy: 0.3817
# Epoch 10/100
# 186/186 [==============================] - ETA: 0s - loss: -77748314035978240.0000 - binary_accuracy: 0.4064
# Epoch 10: val_loss improved from -79708399670919168.00000 to -116051090079744000.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 27s 145ms/step - loss: -77748314035978240.0000 - binary_accuracy: 0.4064 - val_loss: -116051090079744000.0000 - val_binary_accuracy: 0.3817
# Epoch 11/100
# 186/186 [==============================] - ETA: 0s - loss: -110704250933215232.0000 - binary_accuracy: 0.4058
# Epoch 11: val_loss improved from -116051090079744000.00000 to -162245791220498432.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 34s 184ms/step - loss: -110704250933215232.0000 - binary_accuracy: 0.4058 - val_loss: -162245791220498432.0000 - val_binary_accuracy: 0.3788
# Epoch 12/100
# 186/186 [==============================] - ETA: 0s - loss: -151998360029495296.0000 - binary_accuracy: 0.4071
# Epoch 12: val_loss improved from -162245791220498432.00000 to -219375745384841216.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 23s 125ms/step - loss: -151998360029495296.0000 - binary_accuracy: 0.4071 - val_loss: -219375745384841216.0000 - val_binary_accuracy: 0.3780
# Epoch 13/100
# 186/186 [==============================] - ETA: 0s - loss: -202547427863953408.0000 - binary_accuracy: 0.4066
# Epoch 13: val_loss improved from -219375745384841216.00000 to -288651076788289536.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 25s 135ms/step - loss: -202547427863953408.0000 - binary_accuracy: 0.4066 - val_loss: -288651076788289536.0000 - val_binary_accuracy: 0.3796
# Epoch 14/100
# 186/186 [==============================] - ETA: 0s - loss: -263239662263336960.0000 - binary_accuracy: 0.4055
# Epoch 14: val_loss improved from -288651076788289536.00000 to -371134033922359296.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 33s 178ms/step - loss: -263239662263336960.0000 - binary_accuracy: 0.4055 - val_loss: -371134033922359296.0000 - val_binary_accuracy: 0.3807
# Epoch 15/100
# 186/186 [==============================] - ETA: 0s - loss: -335009854269685760.0000 - binary_accuracy: 0.4063
# Epoch 15: val_loss improved from -371134033922359296.00000 to -467967301426085888.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 28s 149ms/step - loss: -335009854269685760.0000 - binary_accuracy: 0.4063 - val_loss: -467967301426085888.0000 - val_binary_accuracy: 0.3817
# Epoch 16/100
# 186/186 [==============================] - ETA: 0s - loss: -418671212990824448.0000 - binary_accuracy: 0.4061
# Epoch 16: val_loss improved from -467967301426085888.00000 to -580122813218684928.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 28s 149ms/step - loss: -418671212990824448.0000 - binary_accuracy: 0.4061 - val_loss: -580122813218684928.0000 - val_binary_accuracy: 0.3664
# Epoch 17/100
# 186/186 [==============================] - ETA: 0s - loss: -515176276273659904.0000 - binary_accuracy: 0.4068
# Epoch 17: val_loss improved from -580122813218684928.00000 to -708833774669922304.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 24s 129ms/step - loss: -515176276273659904.0000 - binary_accuracy: 0.4068 - val_loss: -708833774669922304.0000 - val_binary_accuracy: 0.3817
# Epoch 18/100
# 186/186 [==============================] - ETA: 0s - loss: -625170766681341952.0000 - binary_accuracy: 0.4061
# Epoch 18: val_loss improved from -708833774669922304.00000 to -855081328108896256.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 26s 139ms/step - loss: -625170766681341952.0000 - binary_accuracy: 0.4061 - val_loss: -855081328108896256.0000 - val_binary_accuracy: 0.3685
# Epoch 19/100
# 186/186 [==============================] - ETA: 0s - loss: -749848788201373696.0000 - binary_accuracy: 0.4067
# Epoch 19: val_loss improved from -855081328108896256.00000 to -1019639667160514560.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 24s 129ms/step - loss: -749848788201373696.0000 - binary_accuracy: 0.4067 - val_loss: -1019639667160514560.0000 - val_binary_accuracy: 0.3778
# Epoch 20/100
# 186/186 [==============================] - ETA: 0s - loss: -889867745707950080.0000 - binary_accuracy: 0.4060
# Epoch 20: val_loss improved from -1019639667160514560.00000 to -1204412183891410944.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 25s 135ms/step - loss: -889867745707950080.0000 - binary_accuracy: 0.4060 - val_loss: -1204412183891410944.0000 - val_binary_accuracy: 0.3668
# Epoch 21/100
# 186/186 [==============================] - ETA: 0s - loss: -1046131094161719296.0000 - binary_accuracy: 0.4067
# Epoch 21: val_loss improved from -1204412183891410944.00000 to -1410119539454115840.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 23s 124ms/step - loss: -1046131094161719296.0000 - binary_accuracy: 0.4067 - val_loss: -1410119539454115840.0000 - val_binary_accuracy: 0.3780
# Epoch 22/100
# 186/186 [==============================] - ETA: 0s - loss: -1219594927642509312.0000 - binary_accuracy: 0.4058
# Epoch 22: val_loss improved from -1410119539454115840.00000 to -1637327295142166528.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 30s 159ms/step - loss: -1219594927642509312.0000 - binary_accuracy: 0.4058 - val_loss: -1637327295142166528.0000 - val_binary_accuracy: 0.3778
# Epoch 23/100
# 186/186 [==============================] - ETA: 0s - loss: -1410929604645879808.0000 - binary_accuracy: 0.4059
# Epoch 23: val_loss improved from -1637327295142166528.00000 to -1887647609879789568.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 29s 156ms/step - loss: -1410929604645879808.0000 - binary_accuracy: 0.4059 - val_loss: -1887647609879789568.0000 - val_binary_accuracy: 0.3792
# Epoch 24/100
# 186/186 [==============================] - ETA: 0s - loss: -1621185914690600960.0000 - binary_accuracy: 0.4058
# Epoch 24: val_loss improved from -1887647609879789568.00000 to -2162079527419772928.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 26s 139ms/step - loss: -1621185914690600960.0000 - binary_accuracy: 0.4058 - val_loss: -2162079527419772928.0000 - val_binary_accuracy: 0.3828
# Epoch 25/100
# 186/186 [==============================] - ETA: 0s - loss: -1850947286134161408.0000 - binary_accuracy: 0.4061
# Epoch 25: val_loss improved from -2162079527419772928.00000 to -2461526434003288064.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 32s 171ms/step - loss: -1850947286134161408.0000 - binary_accuracy: 0.4061 - val_loss: -2461526434003288064.0000 - val_binary_accuracy: 0.3754
# Epoch 26/100
# 186/186 [==============================] - ETA: 0s - loss: -2101741765261262848.0000 - binary_accuracy: 0.4063
# Epoch 26: val_loss improved from -2461526434003288064.00000 to -2787520361644687360.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 29s 154ms/step - loss: -2101741765261262848.0000 - binary_accuracy: 0.4063 - val_loss: -2787520361644687360.0000 - val_binary_accuracy: 0.3550
# Epoch 27/100
# 186/186 [==============================] - ETA: 0s - loss: -2373967375281160192.0000 - binary_accuracy: 0.4056
# Epoch 27: val_loss improved from -2787520361644687360.00000 to -3140729675974705152.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 25s 133ms/step - loss: -2373967375281160192.0000 - binary_accuracy: 0.4056 - val_loss: -3140729675974705152.0000 - val_binary_accuracy: 0.3827
# Epoch 28/100
# 186/186 [==============================] - ETA: 0s - loss: -2668597183984435200.0000 - binary_accuracy: 0.4059
# Epoch 28: val_loss improved from -3140729675974705152.00000 to -3522388578795520000.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 24s 130ms/step - loss: -2668597183984435200.0000 - binary_accuracy: 0.4059 - val_loss: -3522388578795520000.0000 - val_binary_accuracy: 0.3687
# Epoch 29/100
# 186/186 [==============================] - ETA: 0s - loss: -2986784853946531840.0000 - binary_accuracy: 0.4069
# Epoch 29: val_loss improved from -3522388578795520000.00000 to -3934547109537120256.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 25s 134ms/step - loss: -2986784853946531840.0000 - binary_accuracy: 0.4069 - val_loss: -3934547109537120256.0000 - val_binary_accuracy: 0.3788
# Epoch 30/100
# 186/186 [==============================] - ETA: 0s - loss: -3328796741859278848.0000 - binary_accuracy: 0.4071
# Epoch 30: val_loss improved from -3934547109537120256.00000 to -4376191243600789504.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 25s 134ms/step - loss: -3328796741859278848.0000 - binary_accuracy: 0.4071 - val_loss: -4376191243600789504.0000 - val_binary_accuracy: 0.3696
# Epoch 31/100
# 186/186 [==============================] - ETA: 0s - loss: -3696919557030543360.0000 - binary_accuracy: 0.4058
# Epoch 31: val_loss improved from -4376191243600789504.00000 to -4851787472096460800.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 23s 125ms/step - loss: -3696919557030543360.0000 - binary_accuracy: 0.4058 - val_loss: -4851787472096460800.0000 - val_binary_accuracy: 0.3646
# Epoch 32/100
# 186/186 [==============================] - ETA: 0s - loss: -4090470227861569536.0000 - binary_accuracy: 0.4054
# Epoch 32: val_loss improved from -4851787472096460800.00000 to -5359747550477811712.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 29s 154ms/step - loss: -4090470227861569536.0000 - binary_accuracy: 0.4054 - val_loss: -5359747550477811712.0000 - val_binary_accuracy: 0.3817
# Epoch 33/100
# 186/186 [==============================] - ETA: 0s - loss: -4511846789212536832.0000 - binary_accuracy: 0.4068
# Epoch 33: val_loss improved from -5359747550477811712.00000 to -5902796893192192000.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 24s 130ms/step - loss: -4511846789212536832.0000 - binary_accuracy: 0.4068 - val_loss: -5902796893192192000.0000 - val_binary_accuracy: 0.3817
# Epoch 34/100
# 186/186 [==============================] - ETA: 0s - loss: -4961371397990383616.0000 - binary_accuracy: 0.4061
# Epoch 34: val_loss improved from -5902796893192192000.00000 to -6481446223390703616.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 25s 137ms/step - loss: -4961371397990383616.0000 - binary_accuracy: 0.4061 - val_loss: -6481446223390703616.0000 - val_binary_accuracy: 0.3814
# Epoch 35/100
# 186/186 [==============================] - ETA: 0s - loss: -5440087765607776256.0000 - binary_accuracy: 0.4064
# Epoch 35: val_loss improved from -6481446223390703616.00000 to -7097077627189460992.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 28s 149ms/step - loss: -5440087765607776256.0000 - binary_accuracy: 0.4064 - val_loss: -7097077627189460992.0000 - val_binary_accuracy: 0.3780
# Epoch 36/100
# 186/186 [==============================] - ETA: 0s - loss: -5949018163000639488.0000 - binary_accuracy: 0.4061
# Epoch 36: val_loss improved from -7097077627189460992.00000 to -7751338173006872576.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 28s 150ms/step - loss: -5949018163000639488.0000 - binary_accuracy: 0.4061 - val_loss: -7751338173006872576.0000 - val_binary_accuracy: 0.3865
# Epoch 37/100
# 186/186 [==============================] - ETA: 0s - loss: -6489470459250212864.0000 - binary_accuracy: 0.4061
# Epoch 37: val_loss improved from -7751338173006872576.00000 to -8444638528435912704.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 24s 131ms/step - loss: -6489470459250212864.0000 - binary_accuracy: 0.4061 - val_loss: -8444638528435912704.0000 - val_binary_accuracy: 0.3814
# Epoch 38/100
# 186/186 [==============================] - ETA: 0s - loss: -7062088418414559232.0000 - binary_accuracy: 0.4058
# Epoch 38: val_loss improved from -8444638528435912704.00000 to -9179676895011143680.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 24s 130ms/step - loss: -7062088418414559232.0000 - binary_accuracy: 0.4058 - val_loss: -9179676895011143680.0000 - val_binary_accuracy: 0.3800
# Epoch 39/100
# 186/186 [==============================] - ETA: 0s - loss: -7666811017598337024.0000 - binary_accuracy: 0.4055
# Epoch 39: val_loss improved from -9179676895011143680.00000 to -9956319682069790720.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 28s 149ms/step - loss: -7666811017598337024.0000 - binary_accuracy: 0.4055 - val_loss: -9956319682069790720.0000 - val_binary_accuracy: 0.3800
# Epoch 40/100
# 186/186 [==============================] - ETA: 0s - loss: -8308384298742841344.0000 - binary_accuracy: 0.4060
# Epoch 40: val_loss improved from -9956319682069790720.00000 to -10777096316111552512.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 25s 134ms/step - loss: -8308384298742841344.0000 - binary_accuracy: 0.4060 - val_loss: -10777096316111552512.0000 - val_binary_accuracy: 0.3813
# Epoch 41/100
# 186/186 [==============================] - ETA: 0s - loss: -8984490491336720384.0000 - binary_accuracy: 0.4061
# Epoch 41: val_loss improved from -10777096316111552512.00000 to -11642499928101486592.00000, saving model to /content/drive/My Drive/CS230_FinalReport/models/with_physicsinputs_transformer_stepclass
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# 186/186 [==============================] - 28s 149ms/step - loss: -8984490491336720384.0000 - binary_accuracy: 0.4061 - val_loss: -11642499928101486592.0000 - val_binary_accuracy: 0.3792
# Epoch 42/100
#   4/186 [..............................] - ETA: 16s - loss: -9386899102719016960.0000 - binary_accuracy: 0.4038
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-55b5f4aa72d3> in <cell line: 3>()
#       1 # Train the model, and get the fit history.
#       2
# ----> 3 fit_history = train_model(model,
#       4                           MODEL_FILENAME,
#       5                           X_train, Y_train,
#
# /content/drive/My Drive/CS230_FinalReport/src/models/train_model_utils_transformer.py in train_model(model, model_filename, X_train, Y_train, X_dev, Y_dev, use_earlystopping, shuffle, epochs, batch_size)
#      75
#      76     # Train the model and record the training history.
# ---> 77     fit_history = model.fit(
#      78         X_train,
#      79         Y_train,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in train_function(iterator)
#    1282             def train_function(iterator):
#    1283                 """Runs a training execution with a single step."""
# -> 1284                 return step_function(self, iterator)
#    1285
#    1286             if not self.run_eagerly:
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in step_function(model, iterator)
#    1266                 )
#    1267             data = next(iterator)
# -> 1268             outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1269             outputs = reduce_per_replica(
#    1270                 outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1314       fn = autograph.tf_convert(
#    1315           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1316       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1317
#    1318   def reduce(self, reduce_op, value, axis):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2893       kwargs = {}
#    2894     with self._container_strategy().scope():
# -> 2895       return self._call_for_each_replica(fn, args, kwargs)
#    2896
#    2897   def _call_for_each_replica(self, fn, args, kwargs):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3694   def _call_for_each_replica(self, fn, args, kwargs):
#    3695     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3696       return fn(*args, **kwargs)
#    3697
#    3698   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     593   def wrapper(*args, **kwargs):
#     594     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595       return func(*args, **kwargs)
#     596
#     597   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in run_step(data)
#    1247
#    1248             def run_step(data):
# -> 1249                 outputs = model.train_step(data)
#    1250                 # Ensure counter is updated only if `train_step` succeeds.
#    1251                 with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in train_step(self, data)
#    1048         # Run forward pass.
#    1049         with tf.GradientTape() as tape:
# -> 1050             y_pred = self(x, training=True)
#    1051             loss = self.compute_loss(x, y, y_pred, sample_weight)
#    1052         self._validate_target_and_loss(y, loss)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in __call__(self, *args, **kwargs)
#     556             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     557
# --> 558         return super().__call__(*args, **kwargs)
#     559
#     560     @doc_controls.doc_in_current_and_subclasses
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1121                 call_fn = self._autographed_call()
#    1122
# -> 1123             call_fn = traceback_utils.inject_argument_info_in_traceback(
#    1124                 call_fn,
#    1125                 object_name=(
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in inject_argument_info_in_traceback(fn, object_name)
#     158             del bound_signature
#     159
# --> 160     return tf.__internal__.decorator.make_decorator(fn, error_handler)
#     161
#     162
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/tf_decorator.py in make_decorator(target, decorator_func, decorator_name, decorator_doc, decorator_argspec)
#     134   if decorator_name is None:
#     135     decorator_name = inspect.currentframe().f_back.f_code.co_name
# --> 136   decorator = TFDecorator(decorator_name, target, decorator_doc,
#     137                           decorator_argspec)
#     138   setattr(decorator_func, '_tf_decorator', decorator)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/tf_decorator.py in __init__(self, decorator_name, target, decorator_doc, decorator_argspec)
#     330     elif callable(target):
#     331       try:
# --> 332         self.__signature__ = inspect.signature(target)
#     333       except (TypeError, ValueError):
#     334         # Certain callables such as builtins can not be inspected for signature.
#
# /usr/lib/python3.10/inspect.py in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3252 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3253     """Get a signature object for the passed callable."""
# -> 3254     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3255                                    globals=globals, locals=locals, eval_str=eval_str)
#    3256
#
# /usr/lib/python3.10/inspect.py in from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3000                       follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3001         """Constructs Signature for the given callable object."""
# -> 3002         return _signature_from_callable(obj, sigcls=cls,
#    3003                                         follow_wrapper_chains=follow_wrapped,
#    3004                                         globals=globals, locals=locals, eval_str=eval_str)
#
# /usr/lib/python3.10/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2399         # In this case we skip the first parameter of the underlying
#    2400         # function (usually `self` or `cls`).
# -> 2401         sig = _get_signature_of(obj.__func__)
#    2402
#    2403         if skip_bound_arg:
#
# /usr/lib/python3.10/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2385     """
#    2386
# -> 2387     _get_signature_of = functools.partial(_signature_from_callable,
#    2388                                 follow_wrapper_chains=follow_wrapper_chains,
#    2389                                 skip_bound_arg=skip_bound_arg,
#
# KeyboardInterrupt:

# %%
# Plot train/validation loss across epochs.

plot_title = (EXP_TYPE + ' transformer step class')
save_dir = os.path.join(BASE_DIR, 'reports', 'figures', EXP_TYPE + "_transformer_stepclass", 'training_loss.png')

plt.plot(fit_history.history['loss'], label='loss: train')
plt.plot(fit_history.history['val_loss'], label='loss: validation')
plt.ylabel('loss')
plt.xlabel('epoch number')
plt.title(plot_title)
plt.legend()
plt.savefig(save_dir)

plt.show()

# %%
plt.plot(fit_history.history['val_loss'], label='loss: validation')
plot_title = (EXP_TYPE + ' transformer step class')
save_dir = os.path.join(BASE_DIR, 'reports', 'figures', EXP_TYPE + "_transformer_stepclass", 'training_loss_validationloss.png')

plt.ylabel('loss')
plt.xlabel('epoch number')
plt.title(plot_title)
plt.legend()
plt.savefig(save_dir)

plt.show()
